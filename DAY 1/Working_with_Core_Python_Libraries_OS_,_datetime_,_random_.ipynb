# %% [markdown]
# <a href="https://colab.research.google.com/github/25WH1A05AT/NASSCOM/blob/main/DAY%201/Working_with_Core_Python_Libraries_OS_%2C_datetime_%2C_random_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print("Current Directory:", os.getcwd())
print("Files and Folders:", os.listdir())

os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sensor_reports', 'sample_data']
